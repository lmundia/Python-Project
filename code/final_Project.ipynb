# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Breast-Cancer-Wisconsin.csv')
df

new_df = df.replace({
    'A7': '?'
}, np.NaN)
new_df.head()
# Out:
#        Scn  A2  A3  A4  A5  A6  A7  A8  A9  A10  CLASS
# 0  1000025   5   1   1   1   2   1   3   1    1      2
# 1  1002945   5   4   4   5   7  10   3   2    1      2
# 2  1015425   3   1   1   1   2   2   3   1    1      2
# 3  1016277   6   8   8   1   3   4   3   7    1      2
# 4  1017023   4   1   1   3   2   1   3   1    1      2

# %%
new_df["A7"] = pd.to_numeric(new_df["A7"])
new_df.head()

#return a specific row
new_df.iloc[[23]]
df=new_df

# %%
df[df.isnull().values.any(axis=1)]
#new_df["A7"].isnull().head()
# Out:
#          Scn  A2  A3  A4  A5  A6  A7  A8  A9  A10  CLASS
# 23   1057013   8   4   5   1   2 NaN   7   3    1      4
# 40   1096800   6   6   6   9   6 NaN   7   8    1      2
# 139  1183246   1   1   1   1   1 NaN   2   1    1      2
# 145  1184840   1   1   3   1   2 NaN   2   1    1      2
# 158  1193683   1   1   2   1   3 NaN   1   1    1      2
# 164  1197510   5   1   1   1   2 NaN   3   1    1      2
# 235  1241232   3   1   4   1   2 NaN   3   1    1      2
# 249   169356   3   1   1   1   2 NaN   3   1    1      2
# 275   432809   3   1   3   1   2 NaN   2   1    1      2
# 292   563649   8   8   8   1   2 NaN   6  10    1      4
# 294   606140   1   1   1   1   2 NaN   2   1    1      2
# 297    61634   5   4   3   1   2 NaN   2   3    1      2
# 315   704168   4   6   5   6   7 NaN   4   9    1      2
# 321   733639   3   1   1   1   2 NaN   3   1    1      2
# 411  1238464   1   1   1   1   1 NaN   2   1    1      2
# ...

# %%
print(df.isnull().sum())
# Out:
# Scn       0
# A2        0
# A3        0
# A4        0
# A5        0
# A6        0
# A7       16
# A8        0
# A9        0
# A10       0
# CLASS     0
# dtype: int64

# %%
df =df.fillna(df.mean(skipna=True))

# %%
df.describe()
# Out:
#                 Scn          A2          A3          A4          A5  \
# count  6.990000e+02  699.000000  699.000000  699.000000  699.000000
# mean   1.071704e+06    4.417740    3.134478    3.207439    2.806867
# std    6.170957e+05    2.815741    3.051459    2.971913    2.855379
# min    6.163400e+04    1.000000    1.000000    1.000000    1.000000
# 25%    8.706885e+05    2.000000    1.000000    1.000000    1.000000
# 50%    1.171710e+06    4.000000    1.000000    1.000000    1.000000
# 75%    1.238298e+06    6.000000    5.000000    5.000000    4.000000
# max    1.345435e+07   10.000000   10.000000   10.000000   10.000000
#
#                A6          A7          A8          A9         A10       CLASS
# count  699.000000  699.000000  699.000000  699.000000  699.000000  699.000000
# mean     3.216023    3.544656    3.437768    2.866953    1.589413    2.689557
# std      2.214300    3.601852    2.438364    3.053634    1.715078    0.951273
# ...

# %%
row_count =df.index.shape[0]
column_count= df.shape[1]
print("Number of Observations is:",row_count, "and number of Columns is:",column_count)
# Out:
# Number of Observations is: 699 and number of Columns is: 11

# %%
unique_vals =df.Scn.unique()
unique_vals.size
# Out:
# 645

# %%
df.Scn.unique().size
# Out:
# 645

# %%
hist_df = df.loc[:,'A2':'A10']

# %%
hist_df.head()
# Out:
#    A2  A3  A4  A5  A6    A7  A8  A9  A10
# 0   5   1   1   1   2   1.0   3   1    1
# 1   5   4   4   5   7  10.0   3   2    1
# 2   3   1   1   1   2   2.0   3   1    1
# 3   6   8   8   1   3   4.0   3   7    1
# 4   4   1   1   3   2   1.0   3   1    1

# %%
plt.hist(hist_df, bins='auto')
plt.tight_layout(rect=(0,0,1.2,1.2))
plt.title("Histogram")
plt.show()

# %%
bar_df = df['CLASS']
type_count = df['CLASS'].value_counts().tolist()
objects = ('Benign', 'Malignant')
y_pos = np.arange(len(objects))

#new_df["A7"]
#plt.hist(hist_df, bins='auto')
#plt.tight_layout(rect=(0,0,1.2,1.2))
#plt.title("Histogram")
#plt.show()
#plt.bar(bar_df, , align='center', alpha=0.5)

# %%
type_count
# Out:
# [458, 241]

# %%
plt.bar(y_pos, type_count, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Class Count')
plt.title('Breast Cancer Winsconsin Classes')
plt.show()

# %%
x = df['A7']
y = df['A9']
area = np.pi*15

plt.scatter(x,y,s=area,alpha=0.5)
plt.title('Scatter plot Breast Cancer Winsconsin')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
